# %%
import wandb
import numpy as np
import json

# %%
entity = 'eval-historical-texts'
project = 'named-entity-recognition'
run_id = 'fyz5q011'

language = 'english'

# %%
api = wandb.Api()

run = api.run(f'{entity}/{project}/{run_id}')

run.summary.update({
    'Best - f1-score-micro-partial-all-component': 0.0000,
    'Best - f1-score-micro-partial-all-literal-coarse': 0.5257,
    'Best - f1-score-micro-partial-all-literal-fine': 0.5257,
    'Best - f1-score-micro-partial-all-metonymic-coarse': 0.0000,
    'Best - f1-score-micro-partial-all-metonymic-fine': 0.0000,
    'Best - f1-score-micro-partial-all-nested': 0.0000,

    'Best - f1-score-micro-strict-all-component': 0.0000,
    'Best - f1-score-micro-strict-all-literal-coarse': 0.2854,
    'Best - f1-score-micro-strict-all-literal-fine': 0.2854,
    'Best - f1-score-micro-strict-all-metonymic-coarse': 0.0000,
    'Best - f1-score-micro-strict-all-metonymic-fine': 0.0000,
    'Best - f1-score-micro-strict-all-nested': 0.0000
})


run.config.update({
    "seed": None,
    "device": None,
    "epochs": None,
    "dropout": None,
    "shuffle": None,
    "evaluate": None,
    "language": language,
    "momentum": None,
    "patience": None,
    "challenge": "named-entity-recognition",
    "eval_freq": None,
    "batch_size": None,
    "split_type": None,
    "data_folder": None,
    "joint_model": None,
    "metric_types": None,
    "no_attention": None,
    "resets_limit": None,
    "weight_decay": None,
    "configuration": "rnn-simple",
    "learning_rate": None,
    "output_folder": None,
    "fasttext_model": None,
    "merge_subwords": None,
    "checkpoint_name": f'{language}-baseline',
    "embeddings_size": None,
    "evaluation_type": None,
    "resume_training": None,
    "run_experiments": None,
    "skip_validation": None,
    "entity_tag_types": [
            "literal-fine",
            "literal-coarse",
            "metonymic-fine",
            "metonymic-coarse",
            "component",
            "nested"
        ],
    "experiment_types": None,
    "hidden_dimension": None,
    "number_of_layers": None,
    "pretrained_model": None,
    "bidirectional_rnn": None,
    "checkpoint_folder": None,
    "use_weighted_loss": None,
    "joint_model_amount": None,
    "output_eval_format": None,
    "pretrained_weights": None,
    "fasttext_model_size": None,
    "replace_all_numbers": None,
    "use_manual_features": None,
    "fine_tune_pretrained": None,
    "learn_new_embeddings": None,
    "max_training_minutes": None,
    "character_hidden_size": None,
    "pretrained_max_length": None,
    "pretrained_model_size": None,
    "include_fasttext_model": None,
    "resume_checkpoint_name": None,
    "enable_external_logging": None,
    "fine_tune_learning_rate": None,
    "include_pretrained_model": None,
    "train_dataset_limit_size": None,
    "character_embeddings_size": None,
    "learn_character_embeddings": None,
    "training_reset_epoch_limit": None,
    "fine_tune_after_convergence": None,
    "skip_best_metrics_on_resume": None,
    "reset_training_on_early_stop": None,
    "validation_dataset_limit_size": None,
})


# run.config.update({
#     "fine_tune_pretrained": False,
#     "fine_tune_learning_rate": None,
#     "checkpoint_name": 'french-all--ft-bert-ce32-ch64-h512-e64-l1-bi-d0.5-nonew-spl-d'
# })

run.display_name = f'{language}-baseline'

run.update()
